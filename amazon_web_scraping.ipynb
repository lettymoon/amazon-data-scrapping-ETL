# %% [markdown]
# <a href="https://colab.research.google.com/github/lettymoon/amazon-data-scrapping-ETL/blob/main/amazon_web_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Simple ETL Project - Amazon Web Scraping

# %%
# @title Libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import re
import time
from urllib.parse import urlparse, parse_qs, urlencode, urlunparse

# %%
# @title Extracting of Products
def get_title(soup):
    try:
        return soup.find("span", id="productTitle").get_text(strip=True)
    except Exception:
        return ""

    return title

def get_price(soup):
    try:
        return soup.select_one("span.a-price > span.a-offscreen").get_text(strip=True)
    except Exception:
        try:
            return soup.select_one("#priceblock_ourprice, #priceblock_dealprice").get_text(strip=True)
        except Exception:
            return ""

def get_brand(soup):
    try:
        for row in soup.select("table tr"):
            try:
                th = row.find("th")
                td = row.find("td")
                if th and td and "marca" in th.get_text(strip=True).lower():
                    return td.get_text(strip=True)
            except Exception:
                continue
    except Exception:
        pass

    try:
        byline = soup.select_one("#bylineInfo")
        if byline:
            return byline.get_text(" ", strip=True)
    except Exception:
        pass

    return ""

def get_rating(soup):
    rating = ""
    try:
      text = soup.select_one("span.a-icon-alt").get_text(strip=True)
      m = re.search(r"([\d.,]+)", text)
      rating = m.group(1) if m else text
    except Exception:
        rating = ""
    return rating

def get_review_count(soup):
    try:
        return soup.find("span", id="acrCustomerReviewText").get_text(strip=True)
    except Exception:
        return ""

# %%
if __name__ == '__main__':

    HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0 Safari/537.36', 'Accept-Language': 'pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7'})

    URL = "https://www.amazon.com.br/s?k=cafeteira+barista&__mk_pt_BR=%C3%85M%C3%85%C5%BD%C3%95%C3%91&crid=224BYB5B97ZD6&sprefix=cafeteira+barista%2Caps%2C246&ref=nb_sb_noss"

    webpage = requests.get(URL, headers=HEADERS)

    soup = BeautifulSoup(webpage.content, "html.parser")

    links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})

    links_list = []

    for link in links:
            links_list.append(link.get('href'))

    d = {"title":[], "price":[], "brand":[], "rating":[], "reviews":[]}

    for link in links_list:
        new_webpage = requests.get("https://www.amazon.com.br" + link, headers=HEADERS)

        new_soup = BeautifulSoup(new_webpage.content, "html.parser")

        d['title'].append(get_title(new_soup))
        d['price'].append(get_price(new_soup))
        d['brand'].append(get_brand(new_soup))
        d['rating'].append(get_rating(new_soup))
        d['reviews'].append(get_review_count(new_soup))

    amazon_df = pd.DataFrame.from_dict(d)
    amazon_df['title'].replace('', np.nan, inplace=True)
    amazon_df = amazon_df.dropna(subset=['title'])
    amazon_df.to_csv("amazon_data.csv", header=True, index=False)

# %%
amazon_df
# Out:
#                                                 title       price  \
# 0   MONDIAL Cafeteira Espresso Dolce Crema 20 Bar,...    R$499,99
# 1   MONDIAL Cafeteira Espresso Dolce Latte 20 Bar,...  R$1.009,90
# 2   Cafeteira, Coffe Express 15 Bar, 2 xicaras, Pr...    R$599,90
# 3   MONDIAL Cafeteira Espresso Dolce Crema 20 Bar,...    R$524,99
# 4   Cafeteira Espresso Automática Série 1200 Phili...  R$2.362,00
# 6   Cafeteira Espresso Eos Premium 1,2 Litros com ...    R$379,90
# 7   Cafeteira Espresso Oster Compacta Perfect Brew...  R$1.099,00
# 8    Cafeteira Espresso Oster PrimaLatte Touch - 127V    R$890,01
# 9      Oster CAFETEIRA ESPRESSO OCAF900 DIGITAL, 127V    R$899,99
# 10  Cafeteira Espresso Automática Série 1200 Phili...  R$2.374,90
# 11  Cafeteira Espresso Eos 2 em 1 Italiana com 20 ...    R$479,90
# 12  Cafeteira Espresso Oster Compacta Perfect Brew...  R$1.099,00
# 13  Cafeteira Espresso 3 em 1 Eos Prepara Espresso...    R$898,00
# 14  WAP Cafeteira Espresso Digital AROMA PRIME WCM...    R$621,00
# 15  Cafeteira Espresso Eos Premium 1,2 Litros com ...    R$379,90
# 16  Cafeteira Espresso Oster Nova PrimaLatte Inox ...    R$890,01
# 17  Cafeteira Espresso Oster Xpert Perfect Brew - ...  R$2.249,10
# 18  Cafeteira Espresso Eos 2 em 1 Italiana com 20 ...    R$549,00
# 19  Cafeteira, Coffe Express 15 Bar, 2 xicaras, Pr...    R$438,57
# 20  MONDIAL Máquina de Café Espresso Coffee Cream,...    R$479,90
# 21  Cafeteira Espresso Oster Xpert Perfect Brew - ...  R$2.349,00
# 22  Cafeteira Espresso 3 em 1 Eos Prepara Espresso...    R$898,00
# 23  Cafeteira Elétrica Home Barista Cuisinart Dose...  R$1.999,00
# 24  Cafeteira Espresso Eos Latte Italiana Inox Ecf...    R$789,00
# 25  De'Longhi Máquina de café expresso com bomba d...  R$1.871,69
# 26  Máquina de café expresso de 20 bar, máquina de...    R$765,93
# 27  Máquina de Café Espresso Arno Virtuoso+ CESP, ...    R$558,50
# 28  Cafeteira Elétrica BrewStation Elite, 35 Xícar...    R$649,90
# 29  Cafeteira Espresso Superautomática Série 5500 ...  R$4.703,00
# 30  DELONGHI MAGNIFICA MAQUINA DE CAFÉ ESPRESSO EC...  R$3.586,00
# 31      Nespresso Cafeteira Lattissima One Preta 110V  R$1.899,00
# 32  Combo Cafeteira Espresso Nespresso Vertuo Pop ...    R$814,60
# 33  PHILIPS Baristina Máquina de café expresso, mo...  R$3.263,62
# 34  Gaggia Cafeteira Espresso Manual Evolution Del...  R$1.899,00
# 35  Cafeteira Espresso Passione Branca, 127V - TRE...    R$499,90
# 36  Cafeteira Elétrica Arno OPIO Soleil Steam & Pu...    R$799,00
# 39  Oster Cafeteira Espresso Oster Nova Perfect Br...  R$2.369,00
# 40  Cafeteira Espresso Automática Série 2200, Wali...  R$3.999,00
# 41  Ninja | Cafeteira | Porção única | Brew com cá...  R$1.289,10
# 42  Ninja LUXE CAFÉ Premier Series, máquina de exp...  R$5.789,75
# 43  Cafeteira Espresso Nespresso Essenza Mini Pret...    R$359,00
# 44         Nespresso Vertuo Pop Preta 110V, Cafeteira    R$407,55
# 45       Cafeteira Express 127v Tramontina Prata 110v  R$4.050,90
# 46  Cafeteira Expresso Nescafé Dolce Gusto, Arno, ...    R$429,00
# 47  KRUPS Cafeteira Essential Brewer com 8 xícaras...  R$2.441,72
#
#               brand         rating   reviews
# 0          ‎MONDIAL            4,5     (563)
# 1          ‎MONDIAL            4,1     (228)
# 2           ‎PHILCO            4,5   (1.836)
# 3          ‎MONDIAL            4,5     (562)
# 4   ‎Philips Walita            4,5   (1.095)
# 6              ‎EOS            5,0       (1)
# 7            ‎Oster            4,7      (54)
# 8            ‎Oster            4,6   (1.334)
# 9            ‎Oster            4,0     (455)
# 10  ‎Philips Walita            4,5   (1.095)
# 11             ‎EOS            4,5       (2)
# 12           ‎Oster            4,2      (85)
# 13             ‎EOS            5,0       (4)
# 14             ‎WAP            4,3      (85)
# 15             ‎EOS            3,5       (3)
# 16           ‎Oster            4,6     (167)
# 17           ‎Oster            4,7     (156)
# 18             ‎EOS  Previous page
# 19          ‎PHILCO            4,5   (1.836)
# 20         ‎MONDIAL            4,3   (1.407)
# 21           ‎Oster            4,6     (123)
# 22             ‎EOS            4,6       (3)
# 23       ‎Cuisinart            3,1      (21)
# 24             ‎EOS            3,8     (125)
# 25       ‎De'Longhi            4,2   (7.783)
# 26         ‎XYKJOBC            3,8       (8)
# 27            ‎Arno            3,8      (12)
# 28  ‎Hamilton Beach            4,6     (593)
# 29          ‎Walita            4,5     (164)
# 30       ‎De'Longhi            4,4  (48.699)
# 31       ‎Nespresso            4,7     (439)
# 32       ‎Nespresso            4,5     (119)
# 33         ‎Philips            3,8     (122)
# 34          ‎Gaggia            4,2      (61)
# 35            ‎TRES            4,6   (4.821)
# 36            ‎Arno            4,3      (97)
# 39           ‎Oster            5,0       (2)
# 40  ‎Philips Walita            4,6     (148)
# 41           ‎Ninja            4,4   (5.171)
# 42           ‎Ninja            4,5   (1.342)
# 43       ‎Nespresso            4,8   (6.048)
# 44       ‎Nespresso            4,4   (1.640)
# 45      ‎Tramontina            4,7      (74)
# 46          ‎GOVVOM            4,8     (698)
# 47           ‎KRUPS            3,8     (191)
